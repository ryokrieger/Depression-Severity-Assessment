# %% [markdown]
# # Model Optimisation
#
# This notebook performs hyperparameter optimisation for the six classical ML models across the nine feature-sets:
# - RandomizedSearchCV
# - GridSearchCV
# - BayesSearchCV

# %%
import warnings
warnings.filterwarnings("ignore")
from pathlib import Path
import numpy as np
import pandas as pd
import joblib
import time
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from scipy.stats import randint, uniform

FEATURES_BASE = Path("../data/processed/features")
PROC_BASE = Path("../data/processed/ml")
MODEL_BASE = Path("../models/ml")
FIG_BASE = Path("../figures/ml")

for p in [PROC_BASE, MODEL_BASE, FIG_BASE]:
    p.mkdir(parents=True, exist_ok=True)

METHODS = ["rfe","skb","fscs","etc","pc","mi","mir","mu","vt"]

OPT_MAP = {
    "rfe": "orfe",
    "skb": "oskb",
    "fscs": "ofscs",
    "etc": "oetc",
    "pc": "opc",
    "mi": "omi",
    "mir": "omir",
    "mu": "omu",
    "vt": "ovt"
}

RANDOM_STATE = 42
CV = StratifiedKFold(n_splits=3, shuffle=True, random_state=RANDOM_STATE)

try:
    from skopt import BayesSearchCV
except Exception:
    try:
        from skopt import BayesSearchCV
    except Exception as e:
        raise ImportError("skopt (scikit-optimize) not found. Install scikit-optimize to use Bayesian optimisation.") from e

print("Configuration OK. Methods:", METHODS)
# Out:
# Configuration OK. Methods: ['rfe', 'skb', 'fscs', 'etc', 'pc', 'mi', 'mir', 'mu', 'vt']

# %% [markdown]
# ## Hyperparameter Spaces

# %%
PARAM_DIST = {
    "Logistic Regression": {
        "C": uniform(0.001, 10),
        "penalty": ["l2"],
        "solver": ["lbfgs", "saga"],
        "max_iter": [500]
    },
    "Gradient Boosting": {
        "n_estimators": randint(50, 300),
        "learning_rate": uniform(0.01, 0.5),
        "max_depth": randint(2, 8),
        "subsample": uniform(0.5, 0.5)
    },
    "KNN": {
        "n_neighbors": randint(1, 31),
        "weights": ["uniform", "distance"],
        "p": [1, 2]
    },
    "Random Forest": {
        "n_estimators": randint(50, 400),
        "max_depth": randint(3, 20),
        "max_features": ["sqrt", "log2", None]
    },
    "Decision Tree": {
        "max_depth": randint(1, 20),
        "min_samples_split": randint(2, 20),
        "min_samples_leaf": randint(1, 20)
    },
    "SVM": {
        "C": uniform(0.01, 100),
        "kernel": ["rbf", "poly"],
        "gamma": ["scale", "auto"]
    }
}

PARAM_GRID = {
    "Logistic Regression": {
        "C": [0.01, 0.1, 1, 10],
        "solver": ["lbfgs"],
        "penalty": ["l2"]
    },
    "Gradient Boosting": {
        "n_estimators": [100, 200],
        "learning_rate": [0.01, 0.1],
        "max_depth": [3, 5]
    },
    "KNN": {
        "n_neighbors": [3,5,7,9],
        "weights": ["uniform","distance"],
        "p": [1,2]
    },
    "Random Forest": {
        "n_estimators": [100, 200],
        "max_depth": [None, 10, 20]
    },
    "Decision Tree": {
        "max_depth": [None, 5, 10],
        "min_samples_split": [2, 5, 10]
    },
    "SVM": {
        "C": [0.1, 1, 10],
        "kernel": ["rbf"],
        "gamma": ["scale"]
    }
}

BAYES_SPACE = {
    "Logistic Regression": {
        "C": (1e-3, 100.0, "log-uniform"),
        "solver": ["lbfgs"],
        "penalty": ["l2"]
    },
    "Gradient Boosting": {
        "n_estimators": (50, 300),
        "learning_rate": (0.01, 0.5, "log-uniform"),
        "max_depth": (2, 8)
    },
    "KNN": {
        "n_neighbors": (1, 31),
        "weights": ["uniform", "distance"],
        "p": [1, 2]
    },
    "Random Forest": {
        "n_estimators": (50, 400),
        "max_depth": (3, 30)
    },
    "Decision Tree": {
        "max_depth": (1, 30),
        "min_samples_split": (2, 50)
    },
    "SVM": {
        "C": (1e-2, 100.0, "log-uniform"),
        "kernel": ["rbf"],
        "gamma": ["scale", "auto"]
    }
}

# %% [markdown]
# ## Helper Functions

# %%
def compute_metrics(y_true, y_pred):
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, average="weighted", zero_division=0)
    rec = recall_score(y_true, y_pred, average="weighted", zero_division=0)
    f1 = f1_score(y_true, y_pred, average="weighted", zero_division=0)
    return {"Accuracy": acc, "Precision": prec, "Recall": rec, "F1": f1}

def save_confusion_matrix(y_true, y_pred, out_path, title):
    cm = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(5,4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax)
    ax.set_xlabel("Predicted"); ax.set_ylabel("True"); ax.set_title(title)
    fig.savefig(out_path, dpi=300, bbox_inches="tight")
    plt.close(fig)

def run_optimizer(name, model, param_space, X_train, y_train, optimizer_type="random", n_iter=30):
    if optimizer_type == "random":
        search = RandomizedSearchCV(model, param_distributions=param_space, n_iter=n_iter, cv=CV,
                                    scoring="accuracy", n_jobs=-1, random_state=RANDOM_STATE, verbose=0)
    elif optimizer_type == "grid":
        search = GridSearchCV(model, param_grid=param_space, cv=CV, scoring="accuracy", n_jobs=-1, verbose=0)
    elif optimizer_type == "bayes":
        search = BayesSearchCV(model, search_spaces=param_space, n_iter=n_iter, cv=CV, scoring="accuracy",
                               n_jobs=-1, random_state=RANDOM_STATE, verbose=0)
    else:
        raise ValueError("Unknown optimizer_type")
    start = time.time()
    search.fit(X_train, y_train)
    end = time.time()
    return search, end - start

# %% [markdown]
# ## Model Definitions

# %%
MODELS = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=RANDOM_STATE),
    "Gradient Boosting": GradientBoostingClassifier(random_state=RANDOM_STATE),
    "KNN": KNeighborsClassifier(),
    "Random Forest": RandomForestClassifier(random_state=RANDOM_STATE),
    "Decision Tree": DecisionTreeClassifier(random_state=RANDOM_STATE),
    "SVM": SVC(probability=True, random_state=RANDOM_STATE)
}

# %% [markdown]
# ## Main Optimisation Loop

# %%
n_iter_rand = 30
n_iter_bayes = 30

for method in tqdm(METHODS, desc="Methods"):
    feat_dir = FEATURES_BASE / method
    if not feat_dir.exists():
        print(f"⚠️ Missing feature folder for {method}; skipping.")
        continue

    train_df = pd.read_csv(feat_dir / "train.csv").dropna(subset=["DepressionEncoded"])
    test_df  = pd.read_csv(feat_dir / "test.csv").dropna(subset=["DepressionEncoded"])
    X_train = train_df.drop(columns=["DepressionEncoded"]).values
    y_train = train_df["DepressionEncoded"].astype(int).values
    X_test  = test_df.drop(columns=["DepressionEncoded"]).values
    y_test  = test_df["DepressionEncoded"].astype(int).values

    opt_folder = OPT_MAP.get(method, method)
    proc_out_base = PROC_BASE / opt_folder
    model_out_base = MODEL_BASE / opt_folder
    fig_out_base = FIG_BASE / opt_folder
    for p in [proc_out_base, model_out_base, fig_out_base]:
        p.mkdir(parents=True, exist_ok=True)

    rand_results = []
    grid_results = []
    bayes_results = []

    for model_name, model in tqdm(MODELS.items(), desc=f"Models ({method})", leave=False):
        print(f"\n=== {method.upper()} :: {model_name} ===")

        pdist = PARAM_DIST.get(model_name, {})
        pgrid = PARAM_GRID.get(model_name, {})
        bspace = BAYES_SPACE.get(model_name, {})

        try:
            print("-> RandomizedSearchCV (n_iter=", n_iter_rand, ")")
            search_rand, t_rand = run_optimizer(model_name, model, pdist, X_train, y_train, optimizer_type="random", n_iter=n_iter_rand)
            best_rand = search_rand.best_estimator_
            y_pred = best_rand.predict(X_test)
            metrics_rand = compute_metrics(y_test, y_pred)
            metrics_rand.update({"Method": method, "Model": model_name, "Optimizer": "Randomized", "TimeSec": t_rand})
            rand_results.append(metrics_rand)

            joblib.dump(best_rand, model_out_base / f"{model_name.lower().replace(' ','_')}_randomized.pkl")
            save_confusion_matrix(y_test, y_pred, fig_out_base / f"{model_name.lower().replace(' ','_')}_randomized_confusion.png",
                                  f"{model_name} Randomized ({method})")
            print(" Randomized done. Metrics:", metrics_rand)
        except Exception as e:
            print(" RandomizedSearchCV failed for", model_name, ":", e)

        try:
            print("-> GridSearchCV")
            if pgrid:
                search_grid, t_grid = run_optimizer(model_name, model, pgrid, X_train, y_train, optimizer_type="grid")
                best_grid = search_grid.best_estimator_
                y_pred = best_grid.predict(X_test)
                metrics_grid = compute_metrics(y_test, y_pred)
                metrics_grid.update({"Method": method, "Model": model_name, "Optimizer": "Grid", "TimeSec": t_grid})
                grid_results.append(metrics_grid)

                joblib.dump(best_grid, model_out_base / f"{model_name.lower().replace(' ','_')}_grid.pkl")
                save_confusion_matrix(y_test, y_pred, fig_out_base / f"{model_name.lower().replace(' ','_')}_grid_confusion.png",
                                      f"{model_name} Grid ({method})")
                print(" Grid done. Metrics:", metrics_grid)
            else:
                print("  No grid defined for", model_name, " — skipping GridSearch")
        except Exception as e:
            print(" GridSearchCV failed for", model_name, ":", e)

        try:
            print("-> BayesSearchCV (n_iter=", n_iter_bayes, ")")
            search_bayes, t_bayes = run_optimizer(model_name, model, bspace, X_train, y_train, optimizer_type="bayes", n_iter=n_iter_bayes)
            best_bayes = search_bayes.best_estimator_
            y_pred = best_bayes.predict(X_test)
            metrics_bayes = compute_metrics(y_test, y_pred)
            metrics_bayes.update({"Method": method, "Model": model_name, "Optimizer": "Bayes", "TimeSec": t_bayes})
            bayes_results.append(metrics_bayes)

            joblib.dump(best_bayes, model_out_base / f"{model_name.lower().replace(' ','_')}_bayes.pkl")
            save_confusion_matrix(y_test, y_pred, fig_out_base / f"{model_name.lower().replace(' ','_')}_bayes_confusion.png",
                                  f"{model_name} Bayes ({method})")
            print(" Bayes done. Metrics:", metrics_bayes)
        except Exception as e:
            print(" BayesSearchCV failed for", model_name, ":", e)

    if rand_results:
        pd.DataFrame(rand_results).to_csv(proc_out_base / "randomized_search_results.csv", index=False)
    if grid_results:
        pd.DataFrame(grid_results).to_csv(proc_out_base / "grid_search_results.csv", index=False)
    if bayes_results:
        pd.DataFrame(bayes_results).to_csv(proc_out_base / "bayes_search_results.csv", index=False)

    print(f"\nSaved results for method: {method} -> {proc_out_base}")
# Out:
# Methods:   0%|          | 0/9 [00:00<?, ?it/s]
# Models (rfe):   0%|          | 0/6 [00:00<?, ?it/s]
# === RFE :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7876543209876543, 'Precision': 0.7879100229434902, 'Recall': 0.7876543209876543, 'F1': 0.7868788029704153, 'Method': 'rfe', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 6.985701560974121}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7876543209876543, 'Precision': 0.7886274129339851, 'Recall': 0.7876543209876543, 'F1': 0.7871443551932665, 'Method': 'rfe', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.08793115615844727}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7876543209876543, 'Precision': 0.7886274129339851, 'Recall': 0.7876543209876543, 'F1': 0.7871443551932665, 'Method': 'rfe', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 15.414624214172363}
#
# === RFE :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7654320987654321, 'Precision': 0.7707390295281243, 'Recall': 0.7654320987654321, 'F1': 0.7661332782853902, 'Method': 'rfe', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 88.20533418655396}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7358024691358025, 'Precision': 0.7393271898229653, 'Recall': 0.7358024691358025, 'F1': 0.735712304154863, 'Method': 'rfe', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 25.581424236297607}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7654320987654321, 'Precision': 0.7687602628012322, 'Recall': 0.7654320987654321, 'F1': 0.7659902298228127, 'Method': 'rfe', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 222.1317675113678}
#
# === RFE :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7333333333333333, 'Precision': 0.7405905941783208, 'Recall': 0.7333333333333333, 'F1': 0.7305845760163577, 'Method': 'rfe', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.9998910427093506}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7209876543209877, 'Precision': 0.7289332466808021, 'Recall': 0.7209876543209877, 'F1': 0.718708320396207, 'Method': 'rfe', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.4792461395263672}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7135802469135802, 'Precision': 0.7201249536379026, 'Recall': 0.7135802469135802, 'F1': 0.7114143025946372, 'Method': 'rfe', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 69.18969798088074}
#
# === RFE :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.762962962962963, 'Precision': 0.7706172109410685, 'Recall': 0.762962962962963, 'F1': 0.7642620668724472, 'Method': 'rfe', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 21.50601315498352}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7679012345679013, 'Precision': 0.7746309979758615, 'Recall': 0.7679012345679013, 'F1': 0.7688641297362491, 'Method': 'rfe', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 4.936997413635254}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7802469135802469, 'Precision': 0.7873793705992711, 'Recall': 0.7802469135802469, 'F1': 0.7818311490464626, 'Method': 'rfe', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 113.65590929985046}
#
# === RFE :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7111111111111111, 'Precision': 0.7115649273078809, 'Recall': 0.7111111111111111, 'F1': 0.7099328509508274, 'Method': 'rfe', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.366579532623291}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.6888888888888889, 'Precision': 0.7036492953405539, 'Recall': 0.6888888888888889, 'F1': 0.683657757475706, 'Method': 'rfe', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.2070760726928711}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7037037037037037, 'Precision': 0.7070987701557286, 'Recall': 0.7037037037037037, 'F1': 0.7036571630931329, 'Method': 'rfe', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 72.10307669639587}
#
# === RFE :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7777777777777778, 'Precision': 0.7781809274181074, 'Recall': 0.7777777777777778, 'F1': 0.777325863642584, 'Method': 'rfe', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 9.691906213760376}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7753086419753087, 'Precision': 0.7779815650595793, 'Recall': 0.7753086419753087, 'F1': 0.7747174599193378, 'Method': 'rfe', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 3.0668089389801025}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7703703703703704, 'Precision': 0.7734883765775706, 'Recall': 0.7703703703703704, 'F1': 0.7700708360193131, 'Method': 'rfe', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 66.08830857276917}
#
# Saved results for method: rfe -> ..\data\processed\ml\orfe
# Models (skb):   0%|          | 0/6 [00:00<?, ?it/s]
# === SKB :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7901234567901234, 'Precision': 0.7911687718850705, 'Recall': 0.7901234567901234, 'F1': 0.7890762813842568, 'Method': 'skb', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 4.678386211395264}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7901234567901234, 'Precision': 0.791502472129668, 'Recall': 0.7901234567901234, 'F1': 0.7890148834596109, 'Method': 'skb', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.4046809673309326}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7901234567901234, 'Precision': 0.7911687718850705, 'Recall': 0.7901234567901234, 'F1': 0.7890762813842568, 'Method': 'skb', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 70.2349796295166}
#
# === SKB :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7308641975308642, 'Precision': 0.732487049140644, 'Recall': 0.7308641975308642, 'F1': 0.7283134658740048, 'Method': 'skb', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 78.39132356643677}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7432098765432099, 'Precision': 0.7423291532614339, 'Recall': 0.7432098765432099, 'F1': 0.7414733879242686, 'Method': 'skb', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 23.7644464969635}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7358024691358025, 'Precision': 0.7395999764822148, 'Recall': 0.7358024691358025, 'F1': 0.7342404678005106, 'Method': 'skb', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 232.94980120658875}
#
# === SKB :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.6839506172839506, 'Precision': 0.6849269946638369, 'Recall': 0.6839506172839506, 'F1': 0.6737213416847014, 'Method': 'skb', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.7790663242340088}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.6666666666666666, 'Precision': 0.6666209273811886, 'Recall': 0.6666666666666666, 'F1': 0.6600883194794641, 'Method': 'skb', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.4522223472595215}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.691358024691358, 'Precision': 0.6911180840593358, 'Recall': 0.691358024691358, 'F1': 0.6866427217632998, 'Method': 'skb', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 42.53471302986145}
#
# === SKB :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7283950617283951, 'Precision': 0.733476302604843, 'Recall': 0.7283950617283951, 'F1': 0.7257046933493324, 'Method': 'skb', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 19.37475824356079}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7432098765432099, 'Precision': 0.743629151155229, 'Recall': 0.7432098765432099, 'F1': 0.7418926609578359, 'Method': 'skb', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 3.3991525173187256}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7358024691358025, 'Precision': 0.7383691723064337, 'Recall': 0.7358024691358025, 'F1': 0.7335454690430419, 'Method': 'skb', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 40.288408517837524}
#
# === SKB :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.6320987654320988, 'Precision': 0.6337864457444893, 'Recall': 0.6320987654320988, 'F1': 0.6309898433334105, 'Method': 'skb', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.3504636287689209}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.6493827160493827, 'Precision': 0.6547595816557037, 'Recall': 0.6493827160493827, 'F1': 0.6479783536958162, 'Method': 'skb', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.13488268852233887}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.6320987654320988, 'Precision': 0.6348649644505897, 'Recall': 0.6320987654320988, 'F1': 0.6332504093627309, 'Method': 'skb', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 63.32278323173523}
#
# === SKB :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7654320987654321, 'Precision': 0.7657690451664938, 'Recall': 0.7654320987654321, 'F1': 0.7653015157592012, 'Method': 'skb', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 9.872467756271362}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7753086419753087, 'Precision': 0.7764764522312346, 'Recall': 0.7753086419753087, 'F1': 0.7754009579206504, 'Method': 'skb', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 1.8324131965637207}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7703703703703704, 'Precision': 0.770248309210173, 'Recall': 0.7703703703703704, 'F1': 0.769947202216147, 'Method': 'skb', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 50.46820020675659}
#
# Saved results for method: skb -> ..\data\processed\ml\oskb
# Models (fscs):   0%|          | 0/6 [00:00<?, ?it/s]
# === FSCS :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7679012345679013, 'Precision': 0.7717094703533359, 'Recall': 0.7679012345679013, 'F1': 0.7688258622025148, 'Method': 'fscs', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 2.3311879634857178}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7679012345679013, 'Precision': 0.7717094703533359, 'Recall': 0.7679012345679013, 'F1': 0.7688258622025148, 'Method': 'fscs', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.23371672630310059}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7654320987654321, 'Precision': 0.7720771877804342, 'Recall': 0.7654320987654321, 'F1': 0.7664392474251562, 'Method': 'fscs', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 50.8630895614624}
#
# === FSCS :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7333333333333333, 'Precision': 0.7362860136999189, 'Recall': 0.7333333333333333, 'F1': 0.7340543646066814, 'Method': 'fscs', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 107.99788236618042}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7604938271604939, 'Precision': 0.7661829143271756, 'Recall': 0.7604938271604939, 'F1': 0.7615989189842602, 'Method': 'fscs', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 25.09023356437683}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7506172839506173, 'Precision': 0.7577400515927086, 'Recall': 0.7506172839506173, 'F1': 0.7509833249214166, 'Method': 'fscs', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 267.8295259475708}
#
# === FSCS :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7160493827160493, 'Precision': 0.7294690141897502, 'Recall': 0.7160493827160493, 'F1': 0.7072920646443306, 'Method': 'fscs', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.9003596305847168}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.6790123456790124, 'Precision': 0.6871136094355419, 'Recall': 0.6790123456790124, 'F1': 0.6750368877516603, 'Method': 'fscs', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.4167912006378174}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7160493827160493, 'Precision': 0.7279684317221321, 'Recall': 0.7160493827160493, 'F1': 0.7088993733380712, 'Method': 'fscs', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 54.5058696269989}
#
# === FSCS :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7555555555555555, 'Precision': 0.7640729911197748, 'Recall': 0.7555555555555555, 'F1': 0.7552197967419397, 'Method': 'fscs', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 19.949772119522095}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7283950617283951, 'Precision': 0.7315499162990202, 'Recall': 0.7283950617283951, 'F1': 0.7279991758936514, 'Method': 'fscs', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 3.0153822898864746}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7580246913580246, 'Precision': 0.7653873285271565, 'Recall': 0.7580246913580246, 'F1': 0.7577785234717297, 'Method': 'fscs', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 96.58349108695984}
#
# === FSCS :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.6691358024691358, 'Precision': 0.6714485028561408, 'Recall': 0.6691358024691358, 'F1': 0.6683848787497021, 'Method': 'fscs', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.34943532943725586}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.6888888888888889, 'Precision': 0.6948849969226314, 'Recall': 0.6888888888888889, 'F1': 0.6887069679875539, 'Method': 'fscs', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.17108893394470215}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.6765432098765433, 'Precision': 0.6819214596730224, 'Recall': 0.6765432098765433, 'F1': 0.6759702059940506, 'Method': 'fscs', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 51.85858130455017}
#
# === FSCS :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7382716049382716, 'Precision': 0.7404732312345481, 'Recall': 0.7382716049382716, 'F1': 0.7381185240487745, 'Method': 'fscs', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 9.702811479568481}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7604938271604939, 'Precision': 0.7648758523199597, 'Recall': 0.7604938271604939, 'F1': 0.76142194468571, 'Method': 'fscs', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 1.8234214782714844}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7604938271604939, 'Precision': 0.7686215427692308, 'Recall': 0.7604938271604939, 'F1': 0.7608654174919138, 'Method': 'fscs', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 48.448328256607056}
#
# Saved results for method: fscs -> ..\data\processed\ml\ofscs
# Models (etc):   0%|          | 0/6 [00:00<?, ?it/s]
# === ETC :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.8, 'Precision': 0.7987000107476299, 'Recall': 0.8, 'F1': 0.7987742016516626, 'Method': 'etc', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 3.3767905235290527}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.8, 'Precision': 0.7987540649531613, 'Recall': 0.8, 'F1': 0.7984704108482832, 'Method': 'etc', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.17650961875915527}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.8, 'Precision': 0.7984192884368655, 'Recall': 0.8, 'F1': 0.7987608641124032, 'Method': 'etc', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 45.20108914375305}
#
# === ETC :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7679012345679013, 'Precision': 0.7686936828421638, 'Recall': 0.7679012345679013, 'F1': 0.7663867478749187, 'Method': 'etc', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 91.08933401107788}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.762962962962963, 'Precision': 0.7656276265258375, 'Recall': 0.762962962962963, 'F1': 0.7639837477837735, 'Method': 'etc', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 25.52726411819458}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7604938271604939, 'Precision': 0.7620834063700408, 'Recall': 0.7604938271604939, 'F1': 0.7580855392724304, 'Method': 'etc', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 247.8290433883667}
#
# === ETC :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7308641975308642, 'Precision': 0.7381344678399884, 'Recall': 0.7308641975308642, 'F1': 0.727799678806248, 'Method': 'etc', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.4240398406982422}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7234567901234568, 'Precision': 0.7265524485726188, 'Recall': 0.7234567901234568, 'F1': 0.7194501915596719, 'Method': 'etc', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.2028970718383789}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7234567901234568, 'Precision': 0.7297413931095548, 'Recall': 0.7234567901234568, 'F1': 0.7204118630212487, 'Method': 'etc', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 11.17177939414978}
#
# === ETC :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.762962962962963, 'Precision': 0.7699197675347199, 'Recall': 0.762962962962963, 'F1': 0.7606640964996269, 'Method': 'etc', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 10.376917362213135}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.745679012345679, 'Precision': 0.7482096161180236, 'Recall': 0.745679012345679, 'F1': 0.7450532326354667, 'Method': 'etc', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 1.7500994205474854}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7703703703703704, 'Precision': 0.772556085497262, 'Recall': 0.7703703703703704, 'F1': 0.7692755167308446, 'Method': 'etc', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 71.68167686462402}
#
# === ETC :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.6814814814814815, 'Precision': 0.6873821991221425, 'Recall': 0.6814814814814815, 'F1': 0.6789481050713788, 'Method': 'etc', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.28239011764526367}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.6790123456790124, 'Precision': 0.6864189937291789, 'Recall': 0.6790123456790124, 'F1': 0.6716762853129465, 'Method': 'etc', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.09676957130432129}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7234567901234568, 'Precision': 0.7209390262101105, 'Recall': 0.7234567901234568, 'F1': 0.719512234334384, 'Method': 'etc', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 45.19162106513977}
#
# === ETC :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7703703703703704, 'Precision': 0.7697771984167383, 'Recall': 0.7703703703703704, 'F1': 0.7694161169436157, 'Method': 'etc', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 11.114720582962036}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7901234567901234, 'Precision': 0.7908730001540458, 'Recall': 0.7901234567901234, 'F1': 0.7893032796446428, 'Method': 'etc', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 3.1393778324127197}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7950617283950617, 'Precision': 0.795088613571893, 'Recall': 0.7950617283950617, 'F1': 0.7938231890527154, 'Method': 'etc', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 59.55687475204468}
#
# Saved results for method: etc -> ..\data\processed\ml\oetc
# Models (pc):   0%|          | 0/6 [00:00<?, ?it/s]
# === PC :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7901234567901234, 'Precision': 0.7911687718850705, 'Recall': 0.7901234567901234, 'F1': 0.7890762813842568, 'Method': 'pc', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 4.8030688762664795}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7901234567901234, 'Precision': 0.791502472129668, 'Recall': 0.7901234567901234, 'F1': 0.7890148834596109, 'Method': 'pc', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.20495986938476562}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7901234567901234, 'Precision': 0.7911687718850705, 'Recall': 0.7901234567901234, 'F1': 0.7890762813842568, 'Method': 'pc', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 51.773319482803345}
#
# === PC :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7308641975308642, 'Precision': 0.732487049140644, 'Recall': 0.7308641975308642, 'F1': 0.7283134658740048, 'Method': 'pc', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 114.09465837478638}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7407407407407407, 'Precision': 0.7398109083049174, 'Recall': 0.7407407407407407, 'F1': 0.7391430865904703, 'Method': 'pc', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 30.037457704544067}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7333333333333333, 'Precision': 0.7374303126999194, 'Recall': 0.7333333333333333, 'F1': 0.7305619168320135, 'Method': 'pc', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 276.50470066070557}
#
# === PC :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.6839506172839506, 'Precision': 0.6849269946638369, 'Recall': 0.6839506172839506, 'F1': 0.6737213416847014, 'Method': 'pc', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.9555065631866455}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.6666666666666666, 'Precision': 0.6666209273811886, 'Recall': 0.6666666666666666, 'F1': 0.6600883194794641, 'Method': 'pc', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.4693715572357178}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7012345679012346, 'Precision': 0.7012650966395138, 'Recall': 0.7012345679012346, 'F1': 0.6917968745046176, 'Method': 'pc', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 47.424009561538696}
#
# === PC :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7407407407407407, 'Precision': 0.7439914891890497, 'Recall': 0.7407407407407407, 'F1': 0.7385356949053459, 'Method': 'pc', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 23.201015949249268}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7308641975308642, 'Precision': 0.7328098783781931, 'Recall': 0.7308641975308642, 'F1': 0.7310087736671844, 'Method': 'pc', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 3.9138388633728027}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7333333333333333, 'Precision': 0.7367714633057373, 'Recall': 0.7333333333333333, 'F1': 0.7299997668139794, 'Method': 'pc', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 89.35624623298645}
#
# === PC :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.6370370370370371, 'Precision': 0.6388603314656242, 'Recall': 0.6370370370370371, 'F1': 0.6359703166625906, 'Method': 'pc', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.2832658290863037}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.6493827160493827, 'Precision': 0.6547595816557037, 'Recall': 0.6493827160493827, 'F1': 0.6479783536958162, 'Method': 'pc', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.11372995376586914}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.654320987654321, 'Precision': 0.656482314534254, 'Recall': 0.654320987654321, 'F1': 0.6551424977425775, 'Method': 'pc', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 43.12727999687195}
#
# === PC :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7654320987654321, 'Precision': 0.7657690451664938, 'Recall': 0.7654320987654321, 'F1': 0.7653015157592012, 'Method': 'pc', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 11.073618173599243}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7753086419753087, 'Precision': 0.7764764522312346, 'Recall': 0.7753086419753087, 'F1': 0.7754009579206504, 'Method': 'pc', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 2.3602969646453857}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7703703703703704, 'Precision': 0.770248309210173, 'Recall': 0.7703703703703704, 'F1': 0.769947202216147, 'Method': 'pc', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 32.93023133277893}
#
# Saved results for method: pc -> ..\data\processed\ml\opc
# Models (mi):   0%|          | 0/6 [00:00<?, ?it/s]
# === MI :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.782716049382716, 'Precision': 0.783310470964792, 'Recall': 0.782716049382716, 'F1': 0.7810032088282496, 'Method': 'mi', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 1.8756027221679688}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7876543209876543, 'Precision': 0.7876156470428777, 'Recall': 0.7876543209876543, 'F1': 0.7857719708975298, 'Method': 'mi', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.0877530574798584}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.782716049382716, 'Precision': 0.783310470964792, 'Recall': 0.782716049382716, 'F1': 0.7810032088282496, 'Method': 'mi', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 28.305572509765625}
#
# === MI :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7308641975308642, 'Precision': 0.7321228369368042, 'Recall': 0.7308641975308642, 'F1': 0.7289838333500029, 'Method': 'mi', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 96.31567001342773}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7333333333333333, 'Precision': 0.7336399703198511, 'Recall': 0.7333333333333333, 'F1': 0.7321530813204208, 'Method': 'mi', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 24.076130867004395}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7308641975308642, 'Precision': 0.7321539161023863, 'Recall': 0.7308641975308642, 'F1': 0.7285939205969456, 'Method': 'mi', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 249.89949464797974}
#
# === MI :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.6987654320987654, 'Precision': 0.7021020112708269, 'Recall': 0.6987654320987654, 'F1': 0.6920131963645566, 'Method': 'mi', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.8387241363525391}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7061728395061728, 'Precision': 0.7057998591979174, 'Recall': 0.7061728395061728, 'F1': 0.7010131345149911, 'Method': 'mi', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.4825453758239746}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.6987654320987654, 'Precision': 0.7021020112708269, 'Recall': 0.6987654320987654, 'F1': 0.6920131963645566, 'Method': 'mi', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 52.33392405509949}
#
# === MI :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7382716049382716, 'Precision': 0.7417569245964788, 'Recall': 0.7382716049382716, 'F1': 0.738828778443566, 'Method': 'mi', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 20.263725996017456}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7530864197530864, 'Precision': 0.757867290287081, 'Recall': 0.7530864197530864, 'F1': 0.754341338122746, 'Method': 'mi', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 3.1524012088775635}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7506172839506173, 'Precision': 0.7542761333456651, 'Recall': 0.7506172839506173, 'F1': 0.7506023743219983, 'Method': 'mi', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 45.90792655944824}
#
# === MI :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.6370370370370371, 'Precision': 0.6344138758001047, 'Recall': 0.6370370370370371, 'F1': 0.635458811799808, 'Method': 'mi', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.10484647750854492}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.6518518518518519, 'Precision': 0.6574194653812226, 'Recall': 0.6518518518518519, 'F1': 0.6507592360287038, 'Method': 'mi', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.05314445495605469}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.6592592592592592, 'Precision': 0.6597581369904613, 'Recall': 0.6592592592592592, 'F1': 0.6591193454631347, 'Method': 'mi', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 14.813016891479492}
#
# === MI :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7481481481481481, 'Precision': 0.7491040136583234, 'Recall': 0.7481481481481481, 'F1': 0.7482239451989013, 'Method': 'mi', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 4.732281684875488}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.762962962962963, 'Precision': 0.765043336115074, 'Recall': 0.762962962962963, 'F1': 0.763226082591213, 'Method': 'mi', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 0.7869579792022705}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7654320987654321, 'Precision': 0.7678793736265002, 'Recall': 0.7654320987654321, 'F1': 0.7659935225548303, 'Method': 'mi', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 21.44251823425293}
#
# Saved results for method: mi -> ..\data\processed\ml\omi
# Models (mir):   0%|          | 0/6 [00:00<?, ?it/s]
# === MIR :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7679012345679013, 'Precision': 0.7672775504207979, 'Recall': 0.7679012345679013, 'F1': 0.767410831721002, 'Method': 'mir', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 1.595515489578247}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7679012345679013, 'Precision': 0.7672775504207979, 'Recall': 0.7679012345679013, 'F1': 0.767410831721002, 'Method': 'mir', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.09590721130371094}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7679012345679013, 'Precision': 0.7672775504207979, 'Recall': 0.7679012345679013, 'F1': 0.767410831721002, 'Method': 'mir', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 13.112157344818115}
#
# === MIR :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.745679012345679, 'Precision': 0.7505175672493789, 'Recall': 0.745679012345679, 'F1': 0.7432845452532263, 'Method': 'mir', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 47.86521577835083}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7481481481481481, 'Precision': 0.7476798206631285, 'Recall': 0.7481481481481481, 'F1': 0.7470344566431874, 'Method': 'mir', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 12.950472831726074}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7407407407407407, 'Precision': 0.7409460192378596, 'Recall': 0.7407407407407407, 'F1': 0.7381597819024994, 'Method': 'mir', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 228.64165806770325}
#
# === MIR :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7135802469135802, 'Precision': 0.7174895414623046, 'Recall': 0.7135802469135802, 'F1': 0.7096020997899048, 'Method': 'mir', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.9454019069671631}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7160493827160493, 'Precision': 0.7190963872247957, 'Recall': 0.7160493827160493, 'F1': 0.7124207579085446, 'Method': 'mir', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.41828370094299316}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7135802469135802, 'Precision': 0.7174895414623046, 'Recall': 0.7135802469135802, 'F1': 0.7096020997899048, 'Method': 'mir', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 54.663355112075806}
#
# === MIR :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7506172839506173, 'Precision': 0.7508191277777334, 'Recall': 0.7506172839506173, 'F1': 0.7505043727797012, 'Method': 'mir', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 18.558339834213257}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7481481481481481, 'Precision': 0.74717715857723, 'Recall': 0.7481481481481481, 'F1': 0.7472743533702885, 'Method': 'mir', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 3.2661819458007812}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7580246913580246, 'Precision': 0.7605963782241434, 'Recall': 0.7580246913580246, 'F1': 0.7570678741957662, 'Method': 'mir', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 72.77679920196533}
#
# === MIR :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7333333333333333, 'Precision': 0.7347454305157671, 'Recall': 0.7333333333333333, 'F1': 0.7330973123861257, 'Method': 'mir', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.10828900337219238}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7086419753086419, 'Precision': 0.7227383835570971, 'Recall': 0.7086419753086419, 'F1': 0.706142832631129, 'Method': 'mir', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.04895734786987305}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.6938271604938272, 'Precision': 0.704547694016044, 'Recall': 0.6938271604938272, 'F1': 0.6933452556497851, 'Method': 'mir', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 10.972569465637207}
#
# === MIR :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7283950617283951, 'Precision': 0.7280455269894522, 'Recall': 0.7283950617283951, 'F1': 0.7263145056325769, 'Method': 'mir', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 4.4528419971466064}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.745679012345679, 'Precision': 0.7454096603586527, 'Recall': 0.745679012345679, 'F1': 0.7451173392731347, 'Method': 'mir', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 0.674799919128418}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7432098765432099, 'Precision': 0.7425195414605482, 'Recall': 0.7432098765432099, 'F1': 0.7422306926066975, 'Method': 'mir', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 50.57057428359985}
#
# Saved results for method: mir -> ..\data\processed\ml\omir
# Models (mu):   0%|          | 0/6 [00:00<?, ?it/s]
# === MU :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7333333333333333, 'Precision': 0.736444418483399, 'Recall': 0.7333333333333333, 'F1': 0.733969923077532, 'Method': 'mu', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 4.545609951019287}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7333333333333333, 'Precision': 0.736444418483399, 'Recall': 0.7333333333333333, 'F1': 0.733969923077532, 'Method': 'mu', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.32160115242004395}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7333333333333333, 'Precision': 0.736444418483399, 'Recall': 0.7333333333333333, 'F1': 0.733969923077532, 'Method': 'mu', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 21.101855754852295}
#
# === MU :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7061728395061728, 'Precision': 0.7083569578752387, 'Recall': 0.7061728395061728, 'F1': 0.7054109900215524, 'Method': 'mu', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 41.421128034591675}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7061728395061728, 'Precision': 0.7071640419218476, 'Recall': 0.7061728395061728, 'F1': 0.7061752508840755, 'Method': 'mu', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 12.164068460464478}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.725925925925926, 'Precision': 0.7284795449043814, 'Recall': 0.725925925925926, 'F1': 0.7245756116586503, 'Method': 'mu', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 119.10636758804321}
#
# === MU :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.6691358024691358, 'Precision': 0.6653516593632616, 'Recall': 0.6691358024691358, 'F1': 0.6617619178937194, 'Method': 'mu', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.4666597843170166}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.6864197530864198, 'Precision': 0.6801011462555955, 'Recall': 0.6864197530864198, 'F1': 0.6784018987782428, 'Method': 'mu', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.2296597957611084}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.6765432098765433, 'Precision': 0.6713264313762067, 'Recall': 0.6765432098765433, 'F1': 0.6670211107976896, 'Method': 'mu', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 11.46280312538147}
#
# === MU :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7234567901234568, 'Precision': 0.729641073246654, 'Recall': 0.7234567901234568, 'F1': 0.7248123365235415, 'Method': 'mu', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 11.278646230697632}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7283950617283951, 'Precision': 0.7344461806889285, 'Recall': 0.7283950617283951, 'F1': 0.7297190960634938, 'Method': 'mu', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 1.9778883457183838}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7234567901234568, 'Precision': 0.7278495796829977, 'Recall': 0.7234567901234568, 'F1': 0.7245396778759436, 'Method': 'mu', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 29.63861918449402}
#
# === MU :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.6345679012345679, 'Precision': 0.6407803575071318, 'Recall': 0.6345679012345679, 'F1': 0.6324329750912163, 'Method': 'mu', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.11695504188537598}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.6567901234567901, 'Precision': 0.6585534651021107, 'Recall': 0.6567901234567901, 'F1': 0.6565499149006401, 'Method': 'mu', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.04358839988708496}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.6345679012345679, 'Precision': 0.6438981501722972, 'Recall': 0.6345679012345679, 'F1': 0.6345110159992821, 'Method': 'mu', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 16.111478567123413}
#
# === MU :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.691358024691358, 'Precision': 0.6970888688237615, 'Recall': 0.691358024691358, 'F1': 0.6933142700695281, 'Method': 'mu', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 5.298526287078857}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7234567901234568, 'Precision': 0.7282516728928716, 'Recall': 0.7234567901234568, 'F1': 0.7243622570178327, 'Method': 'mu', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 0.9544751644134521}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7209876543209877, 'Precision': 0.7251020920163649, 'Recall': 0.7209876543209877, 'F1': 0.7217523486647135, 'Method': 'mu', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 19.252400875091553}
#
# Saved results for method: mu -> ..\data\processed\ml\omu
# Models (vt):   0%|          | 0/6 [00:00<?, ?it/s]
# === VT :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.8049382716049382, 'Precision': 0.8050983081847279, 'Recall': 0.8049382716049382, 'F1': 0.8041277897313581, 'Method': 'vt', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 1.446943998336792}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.8049382716049382, 'Precision': 0.8050983081847279, 'Recall': 0.8049382716049382, 'F1': 0.8041277897313581, 'Method': 'vt', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.08745408058166504}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.8074074074074075, 'Precision': 0.8076007022804617, 'Recall': 0.8074074074074075, 'F1': 0.8064619684866211, 'Method': 'vt', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 12.302035570144653}
#
# === VT :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7802469135802469, 'Precision': 0.7821337910251743, 'Recall': 0.7802469135802469, 'F1': 0.7770064185322368, 'Method': 'vt', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 46.41879415512085}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7506172839506173, 'Precision': 0.7501627256955475, 'Recall': 0.7506172839506173, 'F1': 0.748111984993645, 'Method': 'vt', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 14.993664264678955}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7950617283950617, 'Precision': 0.7948569424964937, 'Recall': 0.7950617283950617, 'F1': 0.7915912430778026, 'Method': 'vt', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 147.8156979084015}
#
# === VT :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.6962962962962963, 'Precision': 0.6921036029771157, 'Recall': 0.6962962962962963, 'F1': 0.6809102712979265, 'Method': 'vt', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.37777280807495117}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7135802469135802, 'Precision': 0.7173162881291112, 'Recall': 0.7135802469135802, 'F1': 0.7059136218228781, 'Method': 'vt', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.19347715377807617}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7086419753086419, 'Precision': 0.7137049257441952, 'Recall': 0.7086419753086419, 'F1': 0.697806623074081, 'Method': 'vt', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 13.226099014282227}
#
# === VT :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.762962962962963, 'Precision': 0.7632261668372778, 'Recall': 0.762962962962963, 'F1': 0.7608255459744596, 'Method': 'vt', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 10.860789060592651}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7654320987654321, 'Precision': 0.7652374259107249, 'Recall': 0.7654320987654321, 'F1': 0.7628556558997436, 'Method': 'vt', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 1.889214277267456}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7654320987654321, 'Precision': 0.7657786653974025, 'Recall': 0.7654320987654321, 'F1': 0.7636558402816095, 'Method': 'vt', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 31.872241258621216}
#
# === VT :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7358024691358025, 'Precision': 0.7328601039567751, 'Recall': 0.7358024691358025, 'F1': 0.7340430045714599, 'Method': 'vt', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.10323381423950195}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7111111111111111, 'Precision': 0.711896005765571, 'Recall': 0.7111111111111111, 'F1': 0.7085698856940688, 'Method': 'vt', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.0426325798034668}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7432098765432099, 'Precision': 0.7434856285665113, 'Recall': 0.7432098765432099, 'F1': 0.7423331479610801, 'Method': 'vt', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 15.739156246185303}
#
# === VT :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7753086419753087, 'Precision': 0.7752442579759726, 'Recall': 0.7753086419753087, 'F1': 0.7737686284904574, 'Method': 'vt', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 4.259616851806641}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7975308641975308, 'Precision': 0.798466146613352, 'Recall': 0.7975308641975308, 'F1': 0.796489268193943, 'Method': 'vt', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 0.7124710083007812}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7703703703703704, 'Precision': 0.7705504512368254, 'Recall': 0.7703703703703704, 'F1': 0.7690909362130356, 'Method': 'vt', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 17.80452585220337}
#
# Saved results for method: vt -> ..\data\processed\ml\ovt

# %% [markdown]
# ## Combine all optimizer results into a single report

# %%
combined_all = []
for method in METHODS:
    opt_folder = OPT_MAP.get(method, method)
    proc_out_base = PROC_BASE / opt_folder
    for fname in ["randomized_search_results.csv", "grid_search_results.csv", "bayes_search_results.csv"]:
        f = proc_out_base / fname
        if f.exists():
            df = pd.read_csv(f)
            df["OptFolder"] = opt_folder
            df["SourceFile"] = fname
            combined_all.append(df)

if combined_all:
    combined_df = pd.concat(combined_all, ignore_index=True)
    combined_df.to_csv(PROC_BASE / "all_optimised_results_summary.csv", index=False)
    display(combined_df.sort_values(["OptFolder", "Model", "Optimizer"], ascending=True))
    print("Combined optimisation summary saved to:", PROC_BASE / "all_optimised_results_summary.csv")
else:
    print("No optimisation results found to combine.")
# Out:
#      Accuracy  Precision    Recall        F1 Method              Model  \
# 70   0.723457   0.720939  0.723457  0.719512    etc      Decision Tree
# 64   0.679012   0.686419  0.679012  0.671676    etc      Decision Tree
# 58   0.681481   0.687382  0.681481  0.678948    etc      Decision Tree
# 67   0.760494   0.762083  0.760494  0.758086    etc  Gradient Boosting
# 61   0.762963   0.765628  0.762963  0.763984    etc  Gradient Boosting
# ..        ...        ...       ...       ...    ...                ...
# 153  0.765432   0.765237  0.765432  0.762856     vt      Random Forest
# 147  0.762963   0.763226  0.762963  0.760826     vt      Random Forest
# 161  0.770370   0.770550  0.770370  0.769091     vt                SVM
# 155  0.797531   0.798466  0.797531  0.796489     vt                SVM
# 149  0.775309   0.775244  0.775309  0.773769     vt                SVM
#
#       Optimizer     TimeSec OptFolder                     SourceFile
# 70        Bayes   45.191621      oetc       bayes_search_results.csv
# 64         Grid    0.096770      oetc        grid_search_results.csv
# 58   Randomized    0.282390      oetc  randomized_search_results.csv
# 67        Bayes  247.829043      oetc       bayes_search_results.csv
# 61         Grid   25.527264      oetc        grid_search_results.csv
# ..          ...         ...       ...                            ...
# 153        Grid    1.889214       ovt        grid_search_results.csv
# 147  Randomized   10.860789       ovt  randomized_search_results.csv
# 161       Bayes   17.804526       ovt       bayes_search_results.csv
# 155        Grid    0.712471       ovt        grid_search_results.csv
# 149  Randomized    4.259617       ovt  randomized_search_results.csv
#
# [162 rows x 10 columns]
# Combined optimisation summary saved to: ..\data\processed\ml\all_optimised_results_summary.csv
