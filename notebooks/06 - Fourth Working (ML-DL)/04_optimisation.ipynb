# %% [markdown]
# # Model Optimisation
#
# This notebook performs hyperparameter optimisation for the six classical ML models across the nine feature-sets:
# - RandomizedSearchCV
# - GridSearchCV
# - BayesSearchCV

# %%
import warnings
warnings.filterwarnings("ignore")
from pathlib import Path
import numpy as np
import pandas as pd
import joblib
import time
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, cross_val_score
from skopt import BayesSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from scipy.stats import randint, uniform

BASE_DIR = Path.cwd().parents[1]
FEATURES_BASE = BASE_DIR / "features" / "04 - Fourth Working"
PROC_BASE = BASE_DIR / "results" / "04 - Fourth Working" / "Optimised"
MODEL_BASE = BASE_DIR / "models" / "04 - Fourth Working" / "Optimised"
FIG_BASE = BASE_DIR / "figures" / "04 - Fourth Working" / "Optimised"

for p in [PROC_BASE, MODEL_BASE, FIG_BASE]:
    p.mkdir(parents=True, exist_ok=True)

METHODS = ["rfe","skb","fscs","etc","pc","mi","mir","mu","vt"]

RANDOM_STATE = 42
CV = StratifiedKFold(n_splits=3, shuffle=True, random_state=RANDOM_STATE)

print("Configuration OK. Methods:", METHODS)
# Out:
# Configuration OK. Methods: ['rfe', 'skb', 'fscs', 'etc', 'pc', 'mi', 'mir', 'mu', 'vt']

# %% [markdown]
# ## Hyperparameter Spaces

# %%
PARAM_DIST = {
    "Logistic Regression": {
        "C": uniform(0.001, 10),
        "penalty": ["l2"],
        "solver": ["lbfgs", "saga"],
        "max_iter": [500]
    },
    "Gradient Boosting": {
        "n_estimators": randint(50, 300),
        "learning_rate": uniform(0.01, 0.5),
        "max_depth": randint(2, 8),
        "subsample": uniform(0.5, 0.5)
    },
    "KNN": {
        "n_neighbors": randint(1, 31),
        "weights": ["uniform", "distance"],
        "p": [1, 2]
    },
    "Random Forest": {
        "n_estimators": randint(50, 400),
        "max_depth": randint(3, 20),
        "max_features": ["sqrt", "log2", None]
    },
    "Decision Tree": {
        "max_depth": randint(1, 20),
        "min_samples_split": randint(2, 20),
        "min_samples_leaf": randint(1, 20)
    },
    "SVM": {
        "C": uniform(0.01, 100),
        "kernel": ["rbf", "poly"],
        "gamma": ["scale", "auto"]
    }
}

PARAM_GRID = {
    "Logistic Regression": {
        "C": [0.01, 0.1, 1, 10],
        "solver": ["lbfgs"],
        "penalty": ["l2"]
    },
    "Gradient Boosting": {
        "n_estimators": [100, 200],
        "learning_rate": [0.01, 0.1],
        "max_depth": [3, 5]
    },
    "KNN": {
        "n_neighbors": [3,5,7,9],
        "weights": ["uniform","distance"],
        "p": [1,2]
    },
    "Random Forest": {
        "n_estimators": [100, 200],
        "max_depth": [None, 10, 20]
    },
    "Decision Tree": {
        "max_depth": [None, 5, 10],
        "min_samples_split": [2, 5, 10]
    },
    "SVM": {
        "C": [0.1, 1, 10],
        "kernel": ["rbf"],
        "gamma": ["scale"]
    }
}

BAYES_SPACE = {
    "Logistic Regression": {
        "C": (1e-3, 100.0, "log-uniform"),
        "solver": ["lbfgs"],
        "penalty": ["l2"]
    },
    "Gradient Boosting": {
        "n_estimators": (50, 300),
        "learning_rate": (0.01, 0.5, "log-uniform"),
        "max_depth": (2, 8)
    },
    "KNN": {
        "n_neighbors": (1, 31),
        "weights": ["uniform", "distance"],
        "p": [1, 2]
    },
    "Random Forest": {
        "n_estimators": (50, 400),
        "max_depth": (3, 30)
    },
    "Decision Tree": {
        "max_depth": (1, 30),
        "min_samples_split": (2, 50)
    },
    "SVM": {
        "C": (1e-2, 100.0, "log-uniform"),
        "kernel": ["rbf"],
        "gamma": ["scale", "auto"]
    }
}

# %% [markdown]
# ## Helper Functions

# %%
def compute_metrics(y_true, y_pred):
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, average="weighted", zero_division=0)
    rec = recall_score(y_true, y_pred, average="weighted", zero_division=0)
    f1 = f1_score(y_true, y_pred, average="weighted", zero_division=0)
    return {"Accuracy": acc, "Precision": prec, "Recall": rec, "F1": f1}

def save_confusion_matrix(y_true, y_pred, out_path, title):
    cm = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(5,4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax)
    ax.set_xlabel("Predicted"); ax.set_ylabel("True"); ax.set_title(title)
    fig.savefig(out_path, dpi=300, bbox_inches="tight")
    plt.close(fig)

def run_optimizer(name, model, param_space, X_train, y_train, optimizer_type="random", n_iter=30):
    if optimizer_type == "random":
        search = RandomizedSearchCV(model, param_distributions=param_space, n_iter=n_iter, cv=CV,
                                    scoring="accuracy", n_jobs=-1, random_state=RANDOM_STATE, verbose=0)
    elif optimizer_type == "grid":
        search = GridSearchCV(model, param_grid=param_space, cv=CV, scoring="accuracy", n_jobs=-1, verbose=0)
    elif optimizer_type == "bayes":
        search = BayesSearchCV(model, search_spaces=param_space, n_iter=n_iter, cv=CV, scoring="accuracy",
                               n_jobs=-1, random_state=RANDOM_STATE, verbose=0)
    else:
        raise ValueError("Unknown optimizer_type")
    start = time.time()
    search.fit(X_train, y_train)
    end = time.time()
    return search, end - start

# %% [markdown]
# ## Model Definitions

# %%
MODELS = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=RANDOM_STATE),
    "Gradient Boosting": GradientBoostingClassifier(random_state=RANDOM_STATE),
    "KNN": KNeighborsClassifier(),
    "Random Forest": RandomForestClassifier(random_state=RANDOM_STATE),
    "Decision Tree": DecisionTreeClassifier(random_state=RANDOM_STATE),
    "SVM": SVC(probability=True, random_state=RANDOM_STATE)
}

# %% [markdown]
# ## Main Optimisation Loop

# %%
n_iter_rand = 30
n_iter_bayes = 30

for method in tqdm(METHODS, desc="Methods"):
    feat_dir = FEATURES_BASE / method
    if not feat_dir.exists():
        print(f"⚠️ Missing feature folder for {method}; skipping.")
        continue

    train_df = pd.read_csv(feat_dir / "train.csv").dropna(subset=["DepressionEncoded"])
    test_df  = pd.read_csv(feat_dir / "test.csv").dropna(subset=["DepressionEncoded"])
    X_train = train_df.drop(columns=["DepressionEncoded"]).values
    y_train = train_df["DepressionEncoded"].astype(int).values
    X_test  = test_df.drop(columns=["DepressionEncoded"]).values
    y_test  = test_df["DepressionEncoded"].astype(int).values

    proc_out_base = PROC_BASE / method
    model_out_base = MODEL_BASE / method
    fig_out_base = FIG_BASE / method
    for p in [proc_out_base, model_out_base, fig_out_base]:
        p.mkdir(parents=True, exist_ok=True)

    rand_results = []
    grid_results = []
    bayes_results = []

    for model_name, model in tqdm(MODELS.items(), desc=f"Models ({method})", leave=False):
        print(f"\n=== {method.upper()} :: {model_name} ===")

        pdist = PARAM_DIST.get(model_name, {})
        pgrid = PARAM_GRID.get(model_name, {})
        bspace = BAYES_SPACE.get(model_name, {})

        try:
            print("-> RandomizedSearchCV (n_iter=", n_iter_rand, ")")
            search_rand, t_rand = run_optimizer(model_name, model, pdist, X_train, y_train, optimizer_type="random", n_iter=n_iter_rand)
            best_rand = search_rand.best_estimator_
            y_pred = best_rand.predict(X_test)
            metrics_rand = compute_metrics(y_test, y_pred)
            metrics_rand.update({"Method": method, "Model": model_name, "Optimizer": "Randomized", "TimeSec": t_rand})
            rand_results.append(metrics_rand)

            joblib.dump(best_rand, model_out_base / f"{model_name.lower().replace(' ','_')}_randomized.pkl")
            save_confusion_matrix(y_test, y_pred, fig_out_base / f"{model_name.lower().replace(' ','_')}_randomized_confusion.png",
                                  f"{model_name} Randomized ({method})")
            print(" Randomized done. Metrics:", metrics_rand)
        except Exception as e:
            print(" RandomizedSearchCV failed for", model_name, ":", e)

        try:
            print("-> GridSearchCV")
            if pgrid:
                search_grid, t_grid = run_optimizer(model_name, model, pgrid, X_train, y_train, optimizer_type="grid")
                best_grid = search_grid.best_estimator_
                y_pred = best_grid.predict(X_test)
                metrics_grid = compute_metrics(y_test, y_pred)
                metrics_grid.update({"Method": method, "Model": model_name, "Optimizer": "Grid", "TimeSec": t_grid})
                grid_results.append(metrics_grid)

                joblib.dump(best_grid, model_out_base / f"{model_name.lower().replace(' ','_')}_grid.pkl")
                save_confusion_matrix(y_test, y_pred, fig_out_base / f"{model_name.lower().replace(' ','_')}_grid_confusion.png",
                                      f"{model_name} Grid ({method})")
                print(" Grid done. Metrics:", metrics_grid)
            else:
                print("  No grid defined for", model_name, " — skipping GridSearch")
        except Exception as e:
            print(" GridSearchCV failed for", model_name, ":", e)

        try:
            print("-> BayesSearchCV (n_iter=", n_iter_bayes, ")")
            search_bayes, t_bayes = run_optimizer(model_name, model, bspace, X_train, y_train, optimizer_type="bayes", n_iter=n_iter_bayes)
            best_bayes = search_bayes.best_estimator_
            y_pred = best_bayes.predict(X_test)
            metrics_bayes = compute_metrics(y_test, y_pred)
            metrics_bayes.update({"Method": method, "Model": model_name, "Optimizer": "Bayes", "TimeSec": t_bayes})
            bayes_results.append(metrics_bayes)

            joblib.dump(best_bayes, model_out_base / f"{model_name.lower().replace(' ','_')}_bayes.pkl")
            save_confusion_matrix(y_test, y_pred, fig_out_base / f"{model_name.lower().replace(' ','_')}_bayes_confusion.png",
                                  f"{model_name} Bayes ({method})")
            print(" Bayes done. Metrics:", metrics_bayes)
        except Exception as e:
            print(" BayesSearchCV failed for", model_name, ":", e)

    if rand_results:
        pd.DataFrame(rand_results).to_csv(proc_out_base / "randomized_search_results.csv", index=False)
    if grid_results:
        pd.DataFrame(grid_results).to_csv(proc_out_base / "grid_search_results.csv", index=False)
    if bayes_results:
        pd.DataFrame(bayes_results).to_csv(proc_out_base / "bayes_search_results.csv", index=False)

    print(f"\nSaved results for method: {method} -> {proc_out_base}")
# Out:
# Methods:   0%|          | 0/9 [00:00<?, ?it/s]
# Models (rfe):   0%|          | 0/6 [00:00<?, ?it/s]
# === RFE :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.8296296296296296, 'Precision': 0.8300297344867618, 'Recall': 0.8296296296296296, 'F1': 0.8295904554605502, 'Method': 'rfe', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 6.109628438949585}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.8296296296296296, 'Precision': 0.8300297344867618, 'Recall': 0.8296296296296296, 'F1': 0.8295904554605502, 'Method': 'rfe', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.08954429626464844}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.8296296296296296, 'Precision': 0.8300297344867618, 'Recall': 0.8296296296296296, 'F1': 0.8295904554605502, 'Method': 'rfe', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 11.60192608833313}
#
# === RFE :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7876543209876543, 'Precision': 0.790046416862536, 'Recall': 0.7876543209876543, 'F1': 0.7880607422832621, 'Method': 'rfe', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 37.046170473098755}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7753086419753087, 'Precision': 0.7764896434509965, 'Recall': 0.7753086419753087, 'F1': 0.7754119491907655, 'Method': 'rfe', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 9.858216285705566}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7950617283950617, 'Precision': 0.7980896385339206, 'Recall': 0.7950617283950617, 'F1': 0.7956465905953748, 'Method': 'rfe', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 133.4235155582428}
#
# === RFE :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7506172839506173, 'Precision': 0.7511902306793058, 'Recall': 0.7506172839506173, 'F1': 0.7503982265109695, 'Method': 'rfe', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.303879976272583}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7481481481481481, 'Precision': 0.7471471550986013, 'Recall': 0.7481481481481481, 'F1': 0.7459366374992886, 'Method': 'rfe', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.14112329483032227}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7432098765432099, 'Precision': 0.742986099880543, 'Recall': 0.7432098765432099, 'F1': 0.7421535429852443, 'Method': 'rfe', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 14.492705345153809}
#
# === RFE :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7802469135802469, 'Precision': 0.7823676268861454, 'Recall': 0.7802469135802469, 'F1': 0.7810026850971781, 'Method': 'rfe', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 8.991005182266235}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.782716049382716, 'Precision': 0.7834598374172601, 'Recall': 0.782716049382716, 'F1': 0.7827203727227089, 'Method': 'rfe', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 1.6026854515075684}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7753086419753087, 'Precision': 0.7779023272467015, 'Recall': 0.7753086419753087, 'F1': 0.7760176855390566, 'Method': 'rfe', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 32.72825598716736}
#
# === RFE :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.745679012345679, 'Precision': 0.7440861086434815, 'Recall': 0.745679012345679, 'F1': 0.7433083645953836, 'Method': 'rfe', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.09633421897888184}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7407407407407407, 'Precision': 0.7377593513525548, 'Recall': 0.7407407407407407, 'F1': 0.7384639467882896, 'Method': 'rfe', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.03829669952392578}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7407407407407407, 'Precision': 0.740554744192274, 'Recall': 0.7407407407407407, 'F1': 0.7398264848199488, 'Method': 'rfe', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 11.999989748001099}
#
# === RFE :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7901234567901234, 'Precision': 0.7902412822376357, 'Recall': 0.7901234567901234, 'F1': 0.789632187856054, 'Method': 'rfe', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 3.4499127864837646}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7975308641975308, 'Precision': 0.7978240652808554, 'Recall': 0.7975308641975308, 'F1': 0.7965852141941581, 'Method': 'rfe', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 0.6643891334533691}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7950617283950617, 'Precision': 0.7958996590060545, 'Recall': 0.7950617283950617, 'F1': 0.7941328408316672, 'Method': 'rfe', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 15.551907539367676}
#
# Saved results for method: rfe -> d:\Programming\Projects\Depression Severity Assessment\results\04 - Fourth Working\Optimised\rfe
# Models (skb):   0%|          | 0/6 [00:00<?, ?it/s]
# === SKB :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.817283950617284, 'Precision': 0.8190286310747521, 'Recall': 0.817283950617284, 'F1': 0.8177827403320362, 'Method': 'skb', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 1.0499181747436523}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.817283950617284, 'Precision': 0.8186726327148609, 'Recall': 0.817283950617284, 'F1': 0.8174306846476589, 'Method': 'skb', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.09150457382202148}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.817283950617284, 'Precision': 0.819014139351832, 'Recall': 0.817283950617284, 'F1': 0.8179392141796757, 'Method': 'skb', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 15.55524730682373}
#
# === SKB :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.745679012345679, 'Precision': 0.7459553457542082, 'Recall': 0.745679012345679, 'F1': 0.7441536085745973, 'Method': 'skb', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 41.12065291404724}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7975308641975308, 'Precision': 0.7977694957331583, 'Recall': 0.7975308641975308, 'F1': 0.7971723727631476, 'Method': 'skb', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 10.858083724975586}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7950617283950617, 'Precision': 0.7950311392562648, 'Recall': 0.7950617283950617, 'F1': 0.7940658317057451, 'Method': 'skb', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 85.6732873916626}
#
# === SKB :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7728395061728395, 'Precision': 0.7748889243883763, 'Recall': 0.7728395061728395, 'F1': 0.7710771399480506, 'Method': 'skb', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.3316690921783447}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7481481481481481, 'Precision': 0.7481298160796871, 'Recall': 0.7481481481481481, 'F1': 0.7466238123072174, 'Method': 'skb', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.14959049224853516}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.745679012345679, 'Precision': 0.7456859896080165, 'Recall': 0.745679012345679, 'F1': 0.7438525007220511, 'Method': 'skb', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 12.142510890960693}
#
# === SKB :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7876543209876543, 'Precision': 0.7888904274767977, 'Recall': 0.7876543209876543, 'F1': 0.7876699794164573, 'Method': 'skb', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 10.234610557556152}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7802469135802469, 'Precision': 0.7804234757599985, 'Recall': 0.7802469135802469, 'F1': 0.7789244233978575, 'Method': 'skb', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 1.7381465435028076}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7802469135802469, 'Precision': 0.7848137555118369, 'Recall': 0.7802469135802469, 'F1': 0.7785626142968735, 'Method': 'skb', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 27.567578077316284}
#
# === SKB :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.6888888888888889, 'Precision': 0.6912623179289845, 'Recall': 0.6888888888888889, 'F1': 0.6858062707100895, 'Method': 'skb', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.09273886680603027}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7012345679012346, 'Precision': 0.7016508921031152, 'Recall': 0.7012345679012346, 'F1': 0.6999486212736731, 'Method': 'skb', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.0418856143951416}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.6962962962962963, 'Precision': 0.6951051352883292, 'Recall': 0.6962962962962963, 'F1': 0.6948701840783786, 'Method': 'skb', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 13.2794668674469}
#
# === SKB :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7925925925925926, 'Precision': 0.7918160863699608, 'Recall': 0.7925925925925926, 'F1': 0.7909120634122085, 'Method': 'skb', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 3.481839656829834}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7950617283950617, 'Precision': 0.7955825856732611, 'Recall': 0.7950617283950617, 'F1': 0.7938015979532945, 'Method': 'skb', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 0.7054705619812012}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7925925925925926, 'Precision': 0.7919751473103671, 'Recall': 0.7925925925925926, 'F1': 0.7913931796619648, 'Method': 'skb', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 18.88254404067993}
#
# Saved results for method: skb -> d:\Programming\Projects\Depression Severity Assessment\results\04 - Fourth Working\Optimised\skb
# Models (fscs):   0%|          | 0/6 [00:00<?, ?it/s]
# === FSCS :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.8197530864197531, 'Precision': 0.8246302923288871, 'Recall': 0.8197530864197531, 'F1': 0.8190469976119586, 'Method': 'fscs', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 0.8104751110076904}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.8197530864197531, 'Precision': 0.8246302923288871, 'Recall': 0.8197530864197531, 'F1': 0.8190469976119586, 'Method': 'fscs', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.08179712295532227}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.8197530864197531, 'Precision': 0.8246302923288871, 'Recall': 0.8197530864197531, 'F1': 0.8190469976119586, 'Method': 'fscs', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 11.367051601409912}
#
# === FSCS :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7777777777777778, 'Precision': 0.783914386859276, 'Recall': 0.7777777777777778, 'F1': 0.7785825864717298, 'Method': 'fscs', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 40.885632038116455}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7901234567901234, 'Precision': 0.7937686705519716, 'Recall': 0.7901234567901234, 'F1': 0.7896386746164098, 'Method': 'fscs', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 11.157114744186401}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7901234567901234, 'Precision': 0.7949538562953197, 'Recall': 0.7901234567901234, 'F1': 0.7893131638714531, 'Method': 'fscs', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 123.24260377883911}
#
# === FSCS :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7481481481481481, 'Precision': 0.7533512047258847, 'Recall': 0.7481481481481481, 'F1': 0.7476250454716826, 'Method': 'fscs', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.28476881980895996}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7333333333333333, 'Precision': 0.7388310000860125, 'Recall': 0.7333333333333333, 'F1': 0.7336227250368675, 'Method': 'fscs', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.15941071510314941}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7481481481481481, 'Precision': 0.7533512047258847, 'Recall': 0.7481481481481481, 'F1': 0.7476250454716826, 'Method': 'fscs', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 14.55908751487732}
#
# === FSCS :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.8074074074074075, 'Precision': 0.8103153604468212, 'Recall': 0.8074074074074075, 'F1': 0.8067963520317449, 'Method': 'fscs', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 9.75406789779663}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7802469135802469, 'Precision': 0.7825856589490368, 'Recall': 0.7802469135802469, 'F1': 0.7789285723999686, 'Method': 'fscs', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 1.8198299407958984}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.8, 'Precision': 0.8028421806776758, 'Recall': 0.8, 'F1': 0.7978711306140278, 'Method': 'fscs', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 33.47058320045471}
#
# === FSCS :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7506172839506173, 'Precision': 0.7549061465100424, 'Recall': 0.7506172839506173, 'F1': 0.7513176232544557, 'Method': 'fscs', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.09589576721191406}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.725925925925926, 'Precision': 0.7267046362287118, 'Recall': 0.725925925925926, 'F1': 0.723288035204342, 'Method': 'fscs', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.04253196716308594}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.762962962962963, 'Precision': 0.764331789333192, 'Recall': 0.762962962962963, 'F1': 0.761988527776188, 'Method': 'fscs', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 10.428710222244263}
#
# === FSCS :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.8074074074074075, 'Precision': 0.8099932671223167, 'Recall': 0.8074074074074075, 'F1': 0.8072669756779193, 'Method': 'fscs', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 3.2352333068847656}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.8123456790123457, 'Precision': 0.8148891518562502, 'Recall': 0.8123456790123457, 'F1': 0.8118711789720239, 'Method': 'fscs', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 0.7901651859283447}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.8123456790123457, 'Precision': 0.8145821251653247, 'Recall': 0.8123456790123457, 'F1': 0.8122126285327993, 'Method': 'fscs', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 20.491766452789307}
#
# Saved results for method: fscs -> d:\Programming\Projects\Depression Severity Assessment\results\04 - Fourth Working\Optimised\fscs
# Models (etc):   0%|          | 0/6 [00:00<?, ?it/s]
# === ETC :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.8419753086419753, 'Precision': 0.8407285815972938, 'Recall': 0.8419753086419753, 'F1': 0.8409320388894963, 'Method': 'etc', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 1.0109901428222656}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.8419753086419753, 'Precision': 0.8407285815972938, 'Recall': 0.8419753086419753, 'F1': 0.8409320388894963, 'Method': 'etc', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.08536124229431152}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.8419753086419753, 'Precision': 0.8407285815972938, 'Recall': 0.8419753086419753, 'F1': 0.8409320388894963, 'Method': 'etc', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 15.85917329788208}
#
# === ETC :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7802469135802469, 'Precision': 0.7827183361484419, 'Recall': 0.7802469135802469, 'F1': 0.7805008540340379, 'Method': 'etc', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 41.0195951461792}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7802469135802469, 'Precision': 0.7821259774406484, 'Recall': 0.7802469135802469, 'F1': 0.780741083081455, 'Method': 'etc', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 10.633909702301025}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7851851851851852, 'Precision': 0.7870958948560733, 'Recall': 0.7851851851851852, 'F1': 0.7854971970916214, 'Method': 'etc', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 133.6378469467163}
#
# === ETC :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7506172839506173, 'Precision': 0.7481352273777991, 'Recall': 0.7506172839506173, 'F1': 0.7476811686964944, 'Method': 'etc', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.2835729122161865}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.762962962962963, 'Precision': 0.7623881402672097, 'Recall': 0.762962962962963, 'F1': 0.7607806230179112, 'Method': 'etc', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.13957476615905762}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.762962962962963, 'Precision': 0.7623881402672097, 'Recall': 0.762962962962963, 'F1': 0.7607806230179112, 'Method': 'etc', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 15.384280681610107}
#
# === ETC :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.8074074074074075, 'Precision': 0.8092769486715504, 'Recall': 0.8074074074074075, 'F1': 0.8072898231172049, 'Method': 'etc', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 9.469608545303345}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.782716049382716, 'Precision': 0.7848687269026551, 'Recall': 0.782716049382716, 'F1': 0.7831350532548509, 'Method': 'etc', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 1.6468603610992432}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7950617283950617, 'Precision': 0.7957730404206504, 'Recall': 0.7950617283950617, 'F1': 0.7946851300680479, 'Method': 'etc', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 31.37681746482849}
#
# === ETC :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7185185185185186, 'Precision': 0.7184492706639228, 'Recall': 0.7185185185185186, 'F1': 0.717851220807784, 'Method': 'etc', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.09940838813781738}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7358024691358025, 'Precision': 0.7377915817492338, 'Recall': 0.7358024691358025, 'F1': 0.7365920687105927, 'Method': 'etc', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.052936553955078125}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.6888888888888889, 'Precision': 0.685354657687991, 'Recall': 0.6888888888888889, 'F1': 0.6868007717537437, 'Method': 'etc', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 14.74719762802124}
#
# === ETC :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.8074074074074075, 'Precision': 0.8084233049512066, 'Recall': 0.8074074074074075, 'F1': 0.8076891900965973, 'Method': 'etc', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 3.2987632751464844}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.817283950617284, 'Precision': 0.8168259971494506, 'Recall': 0.817283950617284, 'F1': 0.8162557171619267, 'Method': 'etc', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 0.6819548606872559}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.8123456790123457, 'Precision': 0.8117199639236422, 'Recall': 0.8123456790123457, 'F1': 0.8112356513931585, 'Method': 'etc', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 19.147173643112183}
#
# Saved results for method: etc -> d:\Programming\Projects\Depression Severity Assessment\results\04 - Fourth Working\Optimised\etc
# Models (pc):   0%|          | 0/6 [00:00<?, ?it/s]
# === PC :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.817283950617284, 'Precision': 0.8190286310747521, 'Recall': 0.817283950617284, 'F1': 0.8177827403320362, 'Method': 'pc', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 0.9870212078094482}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.817283950617284, 'Precision': 0.8186726327148609, 'Recall': 0.817283950617284, 'F1': 0.8174306846476589, 'Method': 'pc', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.08599019050598145}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.817283950617284, 'Precision': 0.819014139351832, 'Recall': 0.817283950617284, 'F1': 0.8179392141796757, 'Method': 'pc', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 15.436972379684448}
#
# === PC :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7950617283950617, 'Precision': 0.7948675999546607, 'Recall': 0.7950617283950617, 'F1': 0.7948809960501153, 'Method': 'pc', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 38.555182695388794}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7975308641975308, 'Precision': 0.7977694957331583, 'Recall': 0.7975308641975308, 'F1': 0.7971723727631476, 'Method': 'pc', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 10.64630651473999}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7876543209876543, 'Precision': 0.7889932549974388, 'Recall': 0.7876543209876543, 'F1': 0.7870860031638266, 'Method': 'pc', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 97.83064842224121}
#
# === PC :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7728395061728395, 'Precision': 0.7748889243883763, 'Recall': 0.7728395061728395, 'F1': 0.7710771399480506, 'Method': 'pc', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.3749661445617676}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7481481481481481, 'Precision': 0.7481298160796871, 'Recall': 0.7481481481481481, 'F1': 0.7466238123072174, 'Method': 'pc', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.1744842529296875}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.745679012345679, 'Precision': 0.7456859896080165, 'Recall': 0.745679012345679, 'F1': 0.7438525007220511, 'Method': 'pc', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 16.996347427368164}
#
# === PC :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7851851851851852, 'Precision': 0.7875053736693608, 'Recall': 0.7851851851851852, 'F1': 0.783606129673009, 'Method': 'pc', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 9.620262861251831}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7777777777777778, 'Precision': 0.7778212808209966, 'Recall': 0.7777777777777778, 'F1': 0.7769182565441901, 'Method': 'pc', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 1.8544549942016602}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7753086419753087, 'Precision': 0.7766712711157155, 'Recall': 0.7753086419753087, 'F1': 0.7745789211061689, 'Method': 'pc', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 32.38784050941467}
#
# === PC :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.6839506172839506, 'Precision': 0.6885935088982599, 'Recall': 0.6839506172839506, 'F1': 0.6817030304139333, 'Method': 'pc', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.10646748542785645}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7037037037037037, 'Precision': 0.70539542755631, 'Recall': 0.7037037037037037, 'F1': 0.7029003934278131, 'Method': 'pc', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.04160356521606445}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.691358024691358, 'Precision': 0.6907785731836094, 'Recall': 0.691358024691358, 'F1': 0.6901377076408949, 'Method': 'pc', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 15.814459562301636}
#
# === PC :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7925925925925926, 'Precision': 0.7918160863699608, 'Recall': 0.7925925925925926, 'F1': 0.7909120634122085, 'Method': 'pc', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 3.462589740753174}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7950617283950617, 'Precision': 0.7955825856732611, 'Recall': 0.7950617283950617, 'F1': 0.7938015979532945, 'Method': 'pc', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 0.730994462966919}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7925925925925926, 'Precision': 0.7919751473103671, 'Recall': 0.7925925925925926, 'F1': 0.7913931796619648, 'Method': 'pc', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 18.792770385742188}
#
# Saved results for method: pc -> d:\Programming\Projects\Depression Severity Assessment\results\04 - Fourth Working\Optimised\pc
# Models (mi):   0%|          | 0/6 [00:00<?, ?it/s]
# === MI :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.817283950617284, 'Precision': 0.8190286310747521, 'Recall': 0.817283950617284, 'F1': 0.8177827403320362, 'Method': 'mi', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 1.0042636394500732}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.817283950617284, 'Precision': 0.8186726327148609, 'Recall': 0.817283950617284, 'F1': 0.8174306846476589, 'Method': 'mi', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.08302783966064453}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.817283950617284, 'Precision': 0.819014139351832, 'Recall': 0.817283950617284, 'F1': 0.8179392141796757, 'Method': 'mi', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 15.640211820602417}
#
# === MI :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7950617283950617, 'Precision': 0.7948675999546607, 'Recall': 0.7950617283950617, 'F1': 0.7948809960501153, 'Method': 'mi', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 40.867871046066284}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7975308641975308, 'Precision': 0.7977694957331583, 'Recall': 0.7975308641975308, 'F1': 0.7971723727631476, 'Method': 'mi', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 10.991243124008179}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.8098765432098766, 'Precision': 0.81060021651909, 'Recall': 0.8098765432098766, 'F1': 0.8101218742209426, 'Method': 'mi', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 123.81293964385986}
#
# === MI :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7728395061728395, 'Precision': 0.7748889243883763, 'Recall': 0.7728395061728395, 'F1': 0.7710771399480506, 'Method': 'mi', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.2893636226654053}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7481481481481481, 'Precision': 0.7481298160796871, 'Recall': 0.7481481481481481, 'F1': 0.7466238123072174, 'Method': 'mi', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.1401810646057129}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.745679012345679, 'Precision': 0.7456859896080165, 'Recall': 0.745679012345679, 'F1': 0.7438525007220511, 'Method': 'mi', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 17.181726694107056}
#
# === MI :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7654320987654321, 'Precision': 0.7663089929880956, 'Recall': 0.7654320987654321, 'F1': 0.7651915358159209, 'Method': 'mi', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 8.96863055229187}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7728395061728395, 'Precision': 0.773462245365674, 'Recall': 0.7728395061728395, 'F1': 0.7726195962300132, 'Method': 'mi', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 1.8055312633514404}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7950617283950617, 'Precision': 0.797412755957797, 'Recall': 0.7950617283950617, 'F1': 0.7946259321776563, 'Method': 'mi', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 31.233863353729248}
#
# === MI :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.6839506172839506, 'Precision': 0.6885935088982599, 'Recall': 0.6839506172839506, 'F1': 0.6817030304139333, 'Method': 'mi', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.10675430297851562}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.6987654320987654, 'Precision': 0.6984725156399261, 'Recall': 0.6987654320987654, 'F1': 0.6975132202670312, 'Method': 'mi', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.04434561729431152}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.6987654320987654, 'Precision': 0.6984725156399261, 'Recall': 0.6987654320987654, 'F1': 0.6975132202670312, 'Method': 'mi', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 10.256047248840332}
#
# === MI :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7925925925925926, 'Precision': 0.7918160863699608, 'Recall': 0.7925925925925926, 'F1': 0.7909120634122085, 'Method': 'mi', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 3.414855480194092}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7950617283950617, 'Precision': 0.7955825856732611, 'Recall': 0.7950617283950617, 'F1': 0.7938015979532945, 'Method': 'mi', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 0.6347084045410156}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7925925925925926, 'Precision': 0.7919751473103671, 'Recall': 0.7925925925925926, 'F1': 0.7913931796619648, 'Method': 'mi', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 15.94938039779663}
#
# Saved results for method: mi -> d:\Programming\Projects\Depression Severity Assessment\results\04 - Fourth Working\Optimised\mi
# Models (mir):   0%|          | 0/6 [00:00<?, ?it/s]
# === MIR :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.8395061728395061, 'Precision': 0.8427692843089194, 'Recall': 0.8395061728395061, 'F1': 0.8396011896468398, 'Method': 'mir', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 1.0732157230377197}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.8444444444444444, 'Precision': 0.8473280919905855, 'Recall': 0.8444444444444444, 'F1': 0.8446967213181774, 'Method': 'mir', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.08527469635009766}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.8444444444444444, 'Precision': 0.8473280919905855, 'Recall': 0.8444444444444444, 'F1': 0.8446967213181774, 'Method': 'mir', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 12.340874910354614}
#
# === MIR :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7975308641975308, 'Precision': 0.7995045734728274, 'Recall': 0.7975308641975308, 'F1': 0.7980885271334799, 'Method': 'mir', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 42.55187129974365}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7925925925925926, 'Precision': 0.7936894357254117, 'Recall': 0.7925925925925926, 'F1': 0.7928623512840087, 'Method': 'mir', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 11.327799558639526}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.8049382716049382, 'Precision': 0.8057397210950358, 'Recall': 0.8049382716049382, 'F1': 0.8045123286357617, 'Method': 'mir', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 119.09932255744934}
#
# === MIR :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7901234567901234, 'Precision': 0.7922709993679083, 'Recall': 0.7901234567901234, 'F1': 0.7891748505309285, 'Method': 'mir', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.2853574752807617}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7580246913580246, 'Precision': 0.7561618442645058, 'Recall': 0.7580246913580246, 'F1': 0.7556695265010736, 'Method': 'mir', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.1390821933746338}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7851851851851852, 'Precision': 0.78694233271452, 'Recall': 0.7851851851851852, 'F1': 0.7831335330641975, 'Method': 'mir', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 11.60376787185669}
#
# === MIR :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.8222222222222222, 'Precision': 0.82360517056305, 'Recall': 0.8222222222222222, 'F1': 0.8224844808802569, 'Method': 'mir', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 10.056008338928223}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.817283950617284, 'Precision': 0.8185131329718739, 'Recall': 0.817283950617284, 'F1': 0.8174683918778176, 'Method': 'mir', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 1.91023850440979}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.8246913580246914, 'Precision': 0.8252022670429604, 'Recall': 0.8246913580246914, 'F1': 0.8246312637276695, 'Method': 'mir', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 33.97497820854187}
#
# === MIR :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.6938271604938272, 'Precision': 0.7009064018678354, 'Recall': 0.6938271604938272, 'F1': 0.6962676501744595, 'Method': 'mir', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.1075124740600586}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7160493827160493, 'Precision': 0.7175545878949072, 'Recall': 0.7160493827160493, 'F1': 0.7156648827256382, 'Method': 'mir', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.04293942451477051}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7333333333333333, 'Precision': 0.7371189999034911, 'Recall': 0.7333333333333333, 'F1': 0.7349168507053812, 'Method': 'mir', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 14.578022480010986}
#
# === MIR :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7950617283950617, 'Precision': 0.7965930619717834, 'Recall': 0.7950617283950617, 'F1': 0.7955214084048549, 'Method': 'mir', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 3.2584030628204346}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.8246913580246914, 'Precision': 0.8279169308495357, 'Recall': 0.8246913580246914, 'F1': 0.8255272738383632, 'Method': 'mir', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 0.667992353439331}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.8271604938271605, 'Precision': 0.8312214967739381, 'Recall': 0.8271604938271605, 'F1': 0.8279615273253312, 'Method': 'mir', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 15.976926326751709}
#
# Saved results for method: mir -> d:\Programming\Projects\Depression Severity Assessment\results\04 - Fourth Working\Optimised\mir
# Models (mu):   0%|          | 0/6 [00:00<?, ?it/s]
# === MU :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7925925925925926, 'Precision': 0.7946889804976945, 'Recall': 0.7925925925925926, 'F1': 0.792786493837252, 'Method': 'mu', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 1.1547038555145264}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7925925925925926, 'Precision': 0.7946889804976945, 'Recall': 0.7925925925925926, 'F1': 0.792786493837252, 'Method': 'mu', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.0870518684387207}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7925925925925926, 'Precision': 0.7946889804976945, 'Recall': 0.7925925925925926, 'F1': 0.792786493837252, 'Method': 'mu', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 15.6791250705719}
#
# === MU :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.8098765432098766, 'Precision': 0.8124433107254014, 'Recall': 0.8098765432098766, 'F1': 0.8098998084511807, 'Method': 'mu', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 40.95576572418213}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.8049382716049382, 'Precision': 0.8073430230861279, 'Recall': 0.8049382716049382, 'F1': 0.805639380382641, 'Method': 'mu', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 11.163178205490112}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.8024691358024691, 'Precision': 0.8053795164035032, 'Recall': 0.8024691358024691, 'F1': 0.8030482379496504, 'Method': 'mu', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 130.89422464370728}
#
# === MU :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7185185185185186, 'Precision': 0.7151646977421345, 'Recall': 0.7185185185185186, 'F1': 0.7146612894749471, 'Method': 'mu', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.3077878952026367}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7160493827160493, 'Precision': 0.7112502949531768, 'Recall': 0.7160493827160493, 'F1': 0.7105719883430233, 'Method': 'mu', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.15368032455444336}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7185185185185186, 'Precision': 0.7151646977421345, 'Recall': 0.7185185185185186, 'F1': 0.7146612894749471, 'Method': 'mu', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 16.963109731674194}
#
# === MU :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7654320987654321, 'Precision': 0.7718816323816748, 'Recall': 0.7654320987654321, 'F1': 0.7669116273134882, 'Method': 'mu', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 9.348068475723267}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7975308641975308, 'Precision': 0.8008397434696751, 'Recall': 0.7975308641975308, 'F1': 0.7981008151074885, 'Method': 'mu', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 1.8193325996398926}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7802469135802469, 'Precision': 0.7862870691968641, 'Recall': 0.7802469135802469, 'F1': 0.7813602166370831, 'Method': 'mu', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 33.71145296096802}
#
# === MU :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7061728395061728, 'Precision': 0.7035782099548878, 'Recall': 0.7061728395061728, 'F1': 0.7036054241480598, 'Method': 'mu', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.10391449928283691}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7111111111111111, 'Precision': 0.710128696202973, 'Recall': 0.7111111111111111, 'F1': 0.7105266429471088, 'Method': 'mu', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.0454401969909668}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7185185185185186, 'Precision': 0.7157821176113859, 'Recall': 0.7185185185185186, 'F1': 0.7165493243054385, 'Method': 'mu', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 15.114895582199097}
#
# === MU :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7901234567901234, 'Precision': 0.7931907145240479, 'Recall': 0.7901234567901234, 'F1': 0.7908883770814427, 'Method': 'mu', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 3.6853840351104736}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7925925925925926, 'Precision': 0.7960146673657253, 'Recall': 0.7925925925925926, 'F1': 0.7935579700444791, 'Method': 'mu', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 0.7638826370239258}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7901234567901234, 'Precision': 0.7944330941467254, 'Recall': 0.7901234567901234, 'F1': 0.7912323908223319, 'Method': 'mu', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 17.21406388282776}
#
# Saved results for method: mu -> d:\Programming\Projects\Depression Severity Assessment\results\04 - Fourth Working\Optimised\mu
# Models (vt):   0%|          | 0/6 [00:00<?, ?it/s]
# === VT :: Logistic Regression ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.8444444444444444, 'Precision': 0.846401606738586, 'Recall': 0.8444444444444444, 'F1': 0.8448222544644943, 'Method': 'vt', 'Model': 'Logistic Regression', 'Optimizer': 'Randomized', 'TimeSec': 0.862295389175415}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.8444444444444444, 'Precision': 0.846401606738586, 'Recall': 0.8444444444444444, 'F1': 0.8448222544644943, 'Method': 'vt', 'Model': 'Logistic Regression', 'Optimizer': 'Grid', 'TimeSec': 0.07359886169433594}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.8444444444444444, 'Precision': 0.846401606738586, 'Recall': 0.8444444444444444, 'F1': 0.8448222544644943, 'Method': 'vt', 'Model': 'Logistic Regression', 'Optimizer': 'Bayes', 'TimeSec': 11.473546981811523}
#
# === VT :: Gradient Boosting ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.8222222222222222, 'Precision': 0.8248036201398773, 'Recall': 0.8222222222222222, 'F1': 0.8227871037082455, 'Method': 'vt', 'Model': 'Gradient Boosting', 'Optimizer': 'Randomized', 'TimeSec': 41.358033657073975}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7851851851851852, 'Precision': 0.7875410243844486, 'Recall': 0.7851851851851852, 'F1': 0.7853870648803644, 'Method': 'vt', 'Model': 'Gradient Boosting', 'Optimizer': 'Grid', 'TimeSec': 11.71300220489502}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.8098765432098766, 'Precision': 0.8144992022732301, 'Recall': 0.8098765432098766, 'F1': 0.8115002463543021, 'Method': 'vt', 'Model': 'Gradient Boosting', 'Optimizer': 'Bayes', 'TimeSec': 121.5103669166565}
#
# === VT :: KNN ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7580246913580246, 'Precision': 0.763068177758401, 'Recall': 0.7580246913580246, 'F1': 0.7590492568944287, 'Method': 'vt', 'Model': 'KNN', 'Optimizer': 'Randomized', 'TimeSec': 0.3108334541320801}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7703703703703704, 'Precision': 0.7753511005361489, 'Recall': 0.7703703703703704, 'F1': 0.7698363206355409, 'Method': 'vt', 'Model': 'KNN', 'Optimizer': 'Grid', 'TimeSec': 0.14179587364196777}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7506172839506173, 'Precision': 0.7556781065902973, 'Recall': 0.7506172839506173, 'F1': 0.7507524434724291, 'Method': 'vt', 'Model': 'KNN', 'Optimizer': 'Bayes', 'TimeSec': 15.085326194763184}
#
# === VT :: Random Forest ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7851851851851852, 'Precision': 0.7917354771085736, 'Recall': 0.7851851851851852, 'F1': 0.7869650109437498, 'Method': 'vt', 'Model': 'Random Forest', 'Optimizer': 'Randomized', 'TimeSec': 9.527575969696045}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.8049382716049382, 'Precision': 0.8079888423096585, 'Recall': 0.8049382716049382, 'F1': 0.8054961521564947, 'Method': 'vt', 'Model': 'Random Forest', 'Optimizer': 'Grid', 'TimeSec': 1.826902151107788}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7876543209876543, 'Precision': 0.7911351650795131, 'Recall': 0.7876543209876543, 'F1': 0.7886130466115018, 'Method': 'vt', 'Model': 'Random Forest', 'Optimizer': 'Bayes', 'TimeSec': 34.07321524620056}
#
# === VT :: Decision Tree ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.7185185185185186, 'Precision': 0.7216608391419708, 'Recall': 0.7185185185185186, 'F1': 0.7182601332136502, 'Method': 'vt', 'Model': 'Decision Tree', 'Optimizer': 'Randomized', 'TimeSec': 0.1028757095336914}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.7086419753086419, 'Precision': 0.7179547103848318, 'Recall': 0.7086419753086419, 'F1': 0.7090380933518188, 'Method': 'vt', 'Model': 'Decision Tree', 'Optimizer': 'Grid', 'TimeSec': 0.05184626579284668}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.7209876543209877, 'Precision': 0.7292990685042183, 'Recall': 0.7209876543209877, 'F1': 0.7204782107252612, 'Method': 'vt', 'Model': 'Decision Tree', 'Optimizer': 'Bayes', 'TimeSec': 14.485085248947144}
#
# === VT :: SVM ===
# -> RandomizedSearchCV (n_iter= 30 )
#  Randomized done. Metrics: {'Accuracy': 0.8148148148148148, 'Precision': 0.8172023461956666, 'Recall': 0.8148148148148148, 'F1': 0.8150256167150012, 'Method': 'vt', 'Model': 'SVM', 'Optimizer': 'Randomized', 'TimeSec': 3.298915386199951}
# -> GridSearchCV
#  Grid done. Metrics: {'Accuracy': 0.8074074074074075, 'Precision': 0.8106948887637588, 'Recall': 0.8074074074074075, 'F1': 0.8069908632231226, 'Method': 'vt', 'Model': 'SVM', 'Optimizer': 'Grid', 'TimeSec': 0.760887861251831}
# -> BayesSearchCV (n_iter= 30 )
#  Bayes done. Metrics: {'Accuracy': 0.817283950617284, 'Precision': 0.8202380845340157, 'Recall': 0.817283950617284, 'F1': 0.8174864714821043, 'Method': 'vt', 'Model': 'SVM', 'Optimizer': 'Bayes', 'TimeSec': 18.065035581588745}
#
# Saved results for method: vt -> d:\Programming\Projects\Depression Severity Assessment\results\04 - Fourth Working\Optimised\vt

# %% [markdown]
# ## Combine all optimizer results into a single report

# %%
combined_all = []
for method in METHODS:
    proc_out_base = PROC_BASE / method
    for fname in ["randomized_search_results.csv", "grid_search_results.csv", "bayes_search_results.csv"]:
        f = proc_out_base / fname
        if f.exists():
            df = pd.read_csv(f)
            df["SourceFile"] = fname
            combined_all.append(df)

if combined_all:
    combined_df = pd.concat(combined_all, ignore_index=True)
    combined_df.to_csv(BASE_DIR / "summary" / "results" / "Results Summary (Optimised)" / "fourth_working_results_summary.csv", index=False)
    display(combined_df.sort_values(["Model", "Optimizer"], ascending=True))
    print("Combined optimisation summary saved to:", BASE_DIR / "summary" / "results" / "Results Summary (Optimised)" / "fourth_working_results_summary.csv")
else:
    print("No optimisation results found to combine.")
# Out:
#      Accuracy  Precision    Recall        F1 Method          Model  \
# 16   0.740741   0.740555  0.740741  0.739826    rfe  Decision Tree
# 34   0.696296   0.695105  0.696296  0.694870    skb  Decision Tree
# 52   0.762963   0.764332  0.762963  0.761989   fscs  Decision Tree
# 70   0.688889   0.685355  0.688889  0.686801    etc  Decision Tree
# 88   0.691358   0.690779  0.691358  0.690138     pc  Decision Tree
# ..        ...        ...       ...       ...    ...            ...
# 77   0.792593   0.791816  0.792593  0.790912     pc            SVM
# 95   0.792593   0.791816  0.792593  0.790912     mi            SVM
# 113  0.795062   0.796593  0.795062  0.795521    mir            SVM
# 131  0.790123   0.793191  0.790123  0.790888     mu            SVM
# 149  0.814815   0.817202  0.814815  0.815026     vt            SVM
#
#       Optimizer    TimeSec                     SourceFile
# 16        Bayes  11.999990       bayes_search_results.csv
# 34        Bayes  13.279467       bayes_search_results.csv
# 52        Bayes  10.428710       bayes_search_results.csv
# 70        Bayes  14.747198       bayes_search_results.csv
# 88        Bayes  15.814460       bayes_search_results.csv
# ..          ...        ...                            ...
# 77   Randomized   3.462590  randomized_search_results.csv
# 95   Randomized   3.414855  randomized_search_results.csv
# 113  Randomized   3.258403  randomized_search_results.csv
# 131  Randomized   3.685384  randomized_search_results.csv
# 149  Randomized   3.298915  randomized_search_results.csv
#
# [162 rows x 9 columns]
# Combined optimisation summary saved to: d:\Programming\Projects\Depression Severity Assessment\summary\results\Results Summary (Optimised)\fourth_working_results_summary.csv
